# %%
# %pylab inline
import numpy as np 
import matplotlib.pyplot as plt 

im1 = plt.imread('20_popc_cho009-1.tif')
print(np.shape(im1))

fig = plt.figure(1, figsize=(9.5, 9))
plt.imshow(im1)
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (560, 512)

# %%
t = np.linspace(-10, 10, 20)
bump = 1 - np.exp(-0.05*t**2)
bump = bump / np.trapz(bump)

kernel = bump[:, np.newaxis] * bump[np.newaxis, :]
print(im1.shape[:2])

kernel_ft = fftpack.fft2(kernel, im1.shape[:2], axes=(0, 1))

im1_ft = fftpack.fft2(im1, axes=(0, 1))
img2_ft = kernel_ft[:, :] * im1_ft
img2 = fftpack.ifft2(img2_ft, axes=(0, 1)).real

imshow(img2)
# Out:
# (560, 512)

# %%
y = np.linspace(-10, 10, 20)
tump = np.exp(-0.05*y**2)
tump = tump / np.trapz(tump)

kernel2 = tump[:, np.newaxis] * tump[np.newaxis, :]
print(im1.shape[:2])

kernel2_ft = fftpack.fft2(kernel2, im1.shape[:2], axes=(0, 1))

im1_ft = fftpack.fft2(im1, axes=(0, 1))
img3_ft = kernel2_ft[:, :] * im1_ft
img3 = fftpack.ifft2(img3_ft, axes=(0, 1)).real

imshow(img3)
# Out:
# (560, 512)

# %%
im2 = plt.imread('colesterol-1.tif')
print(np.shape(im2))

fig = plt.figure(1, figsize=(9.5, 9))
plt.imshow(im2)
plt.show()
# Out:
# (244, 357)

# %%
t = np.linspace(-10, 10, 20)
bump = 1 - np.exp(-0.005*t**2)
bump = bump / np.trapz(bump)

kernel3 = bump[:, np.newaxis] * bump[np.newaxis, :]
print(im2.shape[:2])

kernel3_ft = fftpack.fft2(kernel3, im2.shape[:2], axes=(0, 1))

im2_ft = fftpack.fft2(im2, axes=(0, 1))
img21_ft = kernel3_ft[:, :] * im2_ft
img21 = fftpack.ifft2(img21_ft, axes=(0, 1)).real

imshow(img21)
# Out:
# (244, 357)

# %%
z = np.linspace(-10, 10, 20)
rump = np.exp(-0.005*z**2)
rump = rump / np.trapz(rump)

kernel4 = rump[:, np.newaxis] * rump[np.newaxis, :]
print(im2.shape[:2])

kernel4_ft = fftpack.fft2(kernel4, im2.shape[:2], axes=(0, 1))

im2_ft = fftpack.fft2(img21, axes=(0, 1))
img22_ft = kernel4_ft[:, :] * im2_ft
img22 = fftpack.ifft2(img22_ft, axes=(0, 1)).real

imshow(img22)
# Out:
# (244, 357)

# %%
im3 = plt.imread('ves_full_150_002-1.tif')
print(np.shape(im3))

fig = plt.figure(1, figsize=(9.5, 9))
plt.imshow(im3)
plt.show()
# Out:
# (576, 544)

# %%
t = np.linspace(-10, 10, 20)
bump = 1 - np.exp(-0.005*t**2)
bump = bump / np.trapz(bump)

kernel = bump[:, np.newaxis] * bump[np.newaxis, :]
print(im1.shape[:2])

kernel_ft = fftpack.fft2(kernel, im3.shape[:2], axes=(0, 1))

im3_ft = fftpack.fft2(im3, axes=(0, 1))
img2_ft = kernel_ft[:, :] * im3_ft
img2 = fftpack.ifft2(img2_ft, axes=(0, 1)).real

imshow(img2)
# Out:
# (560, 512)

# %%
t = np.linspace(-10, 10, 20)
bump = np.exp(-0.005*t**2)
bump = bump / np.trapz(bump)

kernel = bump[:, np.newaxis] * bump[np.newaxis, :]
print(im3.shape[:2])

kernel_ft = fftpack.fft2(kernel, im3.shape[:2], axes=(0, 1))

im3_ft = fftpack.fft2(im3, axes=(0, 1))
img3_ft = kernel_ft[:, :] * im3_ft
img3 = fftpack.ifft2(img3_ft, axes=(0, 1)).real

imshow(img3)
# Out:
# (576, 544)
